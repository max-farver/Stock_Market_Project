# %%
import alpha_vantage.timeseries as av
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

ts = av.TimeSeries(key='1W79PCAA71QM8Q85', output_format='pandas')

# %%
# Example from alpha_vantage docs

data, meta_data = ts.get_intraday(symbol='AMD',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.locator_params(nbins=4)
plt.xticks(rotation=90)
plt.show()

# %%
data, meta_data = ts.get_daily(symbol='AMD')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.locator_params(nbins=4)
plt.xticks(rotation=90)
plt.show()

# %%
data.tail()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2019-05-29 15:56:00   140.36   140.42  140.22    140.23    62377.0
# 2019-05-29 15:57:00   140.24   140.30  140.18    140.22    53556.0
# 2019-05-29 15:58:00   140.20   140.25  140.11    140.16    72232.0
# 2019-05-29 15:59:00   140.16   140.33  140.15    140.28    88054.0
# 2019-05-29 16:00:00   140.28   140.48  140.27    140.31   168122.0

# %%
# Out:
# 2019-05-30 07:58:15.257094
